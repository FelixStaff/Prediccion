# S5              12935         12935  12935  11429   8422   1216  10477    649
# S6              12935         12935  12935  11910  10359   8348  12210   6116
# S7              12935         12935  12935  11394  11523    334    810   2522
# S8              12908         12908  12908  11911  10296   1885  11670  12432
# S9              12935         12935  12935   9846   8983    581      0    655
#
#              SO2  TEMPERATURA  HUMEDAD
# Sensor_id
# ANL1       27831         2626     2626
# ANL10      11623         2626     2626
# ANL11      23723         2626     2626
# ANL12      19507         2626     2626
# ANL13      19259         2626     2626
# ANL15       9316         2626     2626
# ANL2       26330         2633     2633
# ANL3       26060         2626     2626
# ANL4       27588         2626     2626
# ANL5       23013         2626     2626
# ANL6       13410         2626     2626
# ANL7       14818         2626     2626
# ANL8       26148         2626     2626
# ANL9        8587         2626     2626
# S1         10488            0        0
# S10         5345            0        0
# S11          393            0        0
# S12         9054            0        0
# S13        10775            0        0
# S15         4403            0        0
# S2           318            0        0
# S3         10289            0        0
# S4          9690            0        0
# S5             0            0        0
# S6          8009            0        0
# S7          4113            0        0
# S8          9914            0        0
# S9           342            0        0

# %%
def clean_data(data):
    # Eliminar la columan llamada 'Unnamed: 0'
    data = data.drop(['Unnamed: 0'], axis=1)
    # Eliminar las columnas que sean solo NaN
    for col in input_CSV:
        data.drop(data[data[col] <= 0].index, inplace=True)
    return data

# %%
data = clean_data(data_raw)
# agarrar solo los datos de la Sensor_id S6 y S7
data_S6 = data[data['Sensor_id'].isin(['ANL4'])]
# order by sensor_id
data_S6 = data_S6.sort_values(by=['Sensor_id'])
#borrar las filas que no tengan O3
data_S6 = data_S6[data_S6['O3'] > 0]
#borrar las filas que no tengan PM10
data_S6 = data_S6[data_S6['PM10'] > 0]
#borrar las filas que no tengan PM25
data_S6 = data_S6[data_S6['PM25'] > 0]
#borrar las filas que no tengan SO2
data_S6 = data_S6[data_S6['SO2'] > 0]
#borrar las filas que no tengan NO2
data_S6 = data_S6[data_S6['NO2'] > 0]
# quitar la columna de Dia
data_S6 = data_S6.drop(['Dia'], axis=1)
# quitar la columna de Registros_id
data_S6 = data_S6.drop(['Registros_id'], axis=1)
# quitar Sensor_id
data_S6 = data_S6.drop(['Sensor_id'], axis=1)
# quitar HUMEDAD
#data_S6 = data_S6.drop(['HUMEDAD'], axis=1)
# quitar TEMPERATURA
#data_S6 = data_S6.drop(['TEMPERATURA'], axis=1)
# convertir nans en 0
data_S6 = data_S6.fillna(0)

# %%
# contar la cantidad de datos que hay por cada Sensor_id
data_S6.describe()
data_S6.head()
# Out:
#         PM10  PM25     O3    CO     NO2     SO2  TEMPERATURA  HUMEDAD
# 2       80.0  11.0  0.045  0.45  0.0090  0.0031          0.0      0.0
# 411133  43.0  23.0  0.005  0.00  0.0132  0.0049          0.0      0.0
# 411132  35.0  21.0  0.008  0.00  0.0135  0.0046          0.0      0.0
# 411131  31.0   6.0  0.011  0.00  0.0142  0.0046          0.0      0.0
# 411130  48.0   7.0  0.018  0.00  0.0130  0.0047          0.0      0.0

# %%
# convertir los datos a numpy
data_S6_numpy = data_S6.to_numpy()

# %%
# importar la libreria para separar en train y test
from sklearn.model_selection import train_test_split

# %%
# Hacer los valores de salida y entrada
# El valor respuesta es el siguiente dato s 
X_data = data_S6_numpy[:-1,:]
y_data = data_S6_numpy[1:,:]
# estandarizar los datos
#"""
X_data = (X_data - X_data.mean(axis=0)) / X_data.std(axis=0)
y_data = (y_data - y_data.mean(axis=0)) / y_data.std(axis=0)
#"""
# separar los datos en train y test
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, shuffle=False)
# convertir los datos a tensor
X_train = torch.from_numpy(X_train).float().to(device)
X_test = torch.from_numpy(X_test).float().to(device)
y_train = torch.from_numpy(y_train).float().to(device)
y_test = torch.from_numpy(y_test).float().to(device)

# %%
# print the shape of the data
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# torch.Size([13228, 8])
# torch.Size([3308, 8])
# torch.Size([13228, 8])
# torch.Size([3308, 8])

# %%
print(data_S6.head(10))
X_train[0:10]
# Out:
#         PM10  PM25     O3    CO     NO2     SO2  TEMPERATURA  HUMEDAD
# 2       80.0  11.0  0.045  0.45  0.0090  0.0031          0.0      0.0
# 411133  43.0  23.0  0.005  0.00  0.0132  0.0049          0.0      0.0
# 411132  35.0  21.0  0.008  0.00  0.0135  0.0046          0.0      0.0
# 411131  31.0   6.0  0.011  0.00  0.0142  0.0046          0.0      0.0
# 411130  48.0   7.0  0.018  0.00  0.0130  0.0047          0.0      0.0
# 411129  52.0   4.0  0.019  0.00  0.0135  0.0050          0.0      0.0
# 411128  78.0  25.0  0.023  0.00  0.0125  0.0057          0.0      0.0
# 411127  98.0  29.0  0.021  0.00  0.0124  0.0067          0.0      0.0
# 411126  92.0  38.0  0.008  0.00  0.0144  0.0071          0.0      0.0
# 411125  55.0  15.0  0.007  0.00  0.0120  0.0072          0.0      0.0
# tensor([[ 0.3780, -0.6560,  0.7861, -0.7713, -0.6408, -0.4113, -0.3940, -0.3823],
#         [-0.5537,  0.3727, -1.1059, -1.3533, -0.1987,  0.2126, -0.3940, -0.3823],
#         [-0.7552,  0.2012, -0.9640, -1.3533, -0.1671,  0.1086, -0.3940, -0.3823],
#         [-0.8559, -1.0846, -0.8221, -1.3533, -0.0935,  0.1086, -0.3940, -0.3823],
#         [-0.4278, -0.9989, -0.4910, -1.3533, -0.2198,  0.1433, -0.3940, -0.3823],
#         [-0.3271, -1.2561, -0.4437, -1.3533, -0.1671,  0.2472, -0.3940, -0.3823],
#         [ 0.3276,  0.5441, -0.2545, -1.3533, -0.2724,  0.4898, -0.3940, -0.3823],
#         [ 0.8312,  0.8870, -0.3491, -1.3533, -0.2829,  0.8364, -0.3940, -0.3823],
#         [ 0.6802,  1.6586, -0.9640, -1.3533, -0.0724,  0.9751, -0.3940, -0.3823],
#         [-0.2516, -0.3131, -1.0113, -1.3533, -0.3250,  1.0097, -0.3940, -0.3823]],
#        device='cuda:0')

# %%
# crear el modelo
# La entrada son los datos numericos y la salida la prediccion de la siguiente hora de esos datos
# usa un modelo recurrente 
from audioop import bias


class O3Predictor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size,device):
        super(O3Predictor, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.device = device
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True,bias=True)
        self.fc1 = nn.Linear(hidden_size, hidden_size, bias=True)
        self.fc2 = nn.Linear(hidden_size, output_size, bias=True)
        #self.fc3 = nn.Linear(hidden_size, output_size)
    def forward(self, x, h):
        # convert x to device
        x, (h, c) = self.lstm(x, h)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        #x = F.leaky_relu(x)
        #x = self.fc3(x)
        return x, (h, c)
    def init_hidden(self, batch_size):
        # set the batch_first to True
        # Xavier initialization to initialize the hidden state
        h = torch.zeros(1, batch_size, self.hidden_size).to(self.device)
        c = torch.zeros(1, batch_size, self.hidden_size).to(self.device)
        h = torch.nn.init.xavier_normal_(h)
        c = torch.nn.init.xavier_normal_(c)
        # initialize the hidden state
        return (h, c)

# %%
# parametros del modelo
Val_loss = []
Trn_loss = []
LSTM_params = {'input_size': X_train.shape[1],
                'hidden_size': 64,
                'output_size': y_train.shape[1],
                'device': device}
O3Pred = O3Predictor(**LSTM_params).to(device)
# funcion de perdida
criterion = nn.MSELoss()

# %%
# load the model weights
O3Pred.load_state_dict(torch.load('Model/O3Pred.pt'))
# Out:
# <All keys matched successfully>

# %%
from math import gamma


EPOCHS = 1000
Learning_rate = 0.005
Batch_size = 512
clip = 0.9
teacher_forcing_ratio = 0.5
context_size = 200
# crear el optimizador
optimizer = torch.optim.AdamW(O3Pred.parameters(), lr=Learning_rate)
# scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10,factor=0.5)

# %%
def plot_model(model, X_test, y_test, O3Only=False):
    model.eval()
    with torch.no_grad():
        hidden = model.init_hidden(1)
        print(hidden[0].shape)
        print(X_test.shape)
        output, hidden = model(X_test.unsqueeze(0), hidden)
        loss = criterion(output, y_test)
        print('Test Loss: {:.6f}'.format(loss.item()))
        print(output.shape)
        print(y_test.shape)
        # mostrar con transparencia el resultado
        if O3Only:
            for i in range(y_test.shape[1]):
                plt.plot(y_test.detach().cpu().numpy()[:,i], label='Ground Truth', alpha = 0.9)
                plt.plot(output.detach().cpu().numpy()[0,:,i], label='Prediction', alpha = 0.4)
                plt.legend()
                plt.show()
        else:
            plt.plot(y_test.detach().cpu().numpy()[:,2], label='Ground Truth', alpha = 0.9)
            plt.plot(output.detach().cpu().numpy()[0,:,2], label='Prediction', alpha = 0.4)
            plt.legend()
            plt.show()

# %%
# entrenar el modelo
for epoch in range(EPOCHS):
    O3Pred.train()
    # pasar los datos a la GPU
    for i in range(0, X_train.shape[0]-Batch_size, Batch_size):
        # crear una batch de datos para el contexto
        X_batch = X_train[i:i+context_size].unsqueeze(1)
        y_batch = y_train[i:i+context_size].unsqueeze(1)
        # despues de este contexto, el modelo usara sus outpues como input
        # pero antes calcular el output del modelo
        # crear el hidden state
        hidden = O3Pred.init_hidden(context_size)
        # crear el output del modelo
        output, hidden = O3Pred(X_batch, hidden)
        # calcular la perdida
        lossContext = criterion(output, y_batch)
        
        # calcular las siguientes horas
        x_next = output[-1,:,:].unsqueeze(0)
        hidden = (hidden[0][:,-1,:].unsqueeze(0), hidden[1][:,-1,:].unsqueeze(0))
        for j in range(1, Batch_size-context_size):
            # crear el input del modelo que es la ultima salida
            # crear el output del modelo
            output, hidden = O3Pred(x_next, hidden)
            #print (output)
            # calcular la perdida
            lossNext = criterion(output, y_train[i+context_size+j].unsqueeze(0))
            # sumar la perdida
            lossContext += lossNext
            #print (lossNext.item())
            # crear el input del modelo que es la ultima salida
            x_next = output[:,-1,:].unsqueeze(0)
        # dividir la perdida por el numero de datos
        lossContext /= Batch_size-context_size
        # calcular la perdida
        loss = lossContext
        # actualizar los pesos
        optimizer.zero_grad()
        loss.backward()
        # clip the gradient
        torch.nn.utils.clip_grad_norm_(O3Pred.parameters(), clip)
        optimizer.step()
    if epoch % 1 == 0:
        print ('Epoch: {} Loss: {:.6f}'.format(epoch, loss.item()))
# Out:
# Epoch: 0 Loss: 0.814183
# Epoch: 1 Loss: 0.832469
# Epoch: 2 Loss: 0.826479
# Epoch: 3 Loss: 0.853016
# Epoch: 4 Loss: 0.849775
# Epoch: 5 Loss: 0.848121
# Epoch: 6 Loss: 0.850905
# Epoch: 7 Loss: 1.720933
# Epoch: 8 Loss: 0.852022
# Epoch: 9 Loss: 0.850943
# Epoch: 10 Loss: 0.849873
# Epoch: 11 Loss: 0.848999
# Epoch: 12 Loss: 0.848420
# Epoch: 13 Loss: 0.849124
# Epoch: 14 Loss: 3.761155
# Epoch: 15 Loss: 4.343089
# Epoch: 16 Loss: 4.023286
# Epoch: 17 Loss: 2.278562
# Epoch: 18 Loss: 3.509592
# Epoch: 19 Loss: 2.551921
# Epoch: 20 Loss: 2.861188
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Felipe de Jesus\OneDrive\Documentos\Programaciones\VisualStudio\Python\MachineLearning\AireNuevoLeon\Prediccion\O3Forecast.ipynb Cell 20' in <cell line: 2>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Felipe%20de%20Jesus/OneDrive/Documentos/Programaciones/VisualStudio/Python/MachineLearning/AireNuevoLeon/Prediccion/O3Forecast.ipynb#ch0000019?line=36'>37</a> # actualizar los pesos
#      <a href='vscode-notebook-cell:/c%3A/Users/Felipe%20de%20Jesus/OneDrive/Documentos/Programaciones/VisualStudio/Python/MachineLearning/AireNuevoLeon/Prediccion/O3Forecast.ipynb#ch0000019?line=37'>38</a> optimizer.zero_grad()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Felipe%20de%20Jesus/OneDrive/Documentos/Programaciones/VisualStudio/Python/MachineLearning/AireNuevoLeon/Prediccion/O3Forecast.ipynb#ch0000019?line=38'>39</a> loss.backward()
#      <a href='vscode-notebook-cell:/c%3A/Users/Felipe%20de%20Jesus/OneDrive/Documentos/Programaciones/VisualStudio/Python/MachineLearning/AireNuevoLeon/Prediccion/O3Forecast.ipynb#ch0000019?line=39'>40</a> # clip the gradient
#      <a href='vscode-notebook-cell:/c%3A/Users/Felipe%20de%20Jesus/OneDrive/Documentos/Programaciones/VisualStudio/Python/MachineLearning/AireNuevoLeon/Prediccion/O3Forecast.ipynb#ch0000019?line=40'>41</a> torch.nn.utils.clip_grad_norm_(O3Pred.parameters(), clip)
#
# File c:\Users\Felipe de Jesus\miniconda3\envs\FLearn\lib\site-packages\torch\_tensor.py:363, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     354 if has_torch_function_unary(self):
#     355     return handle_torch_function(
#     356         Tensor.backward,
#     357         (self,),
#    (...)
#     361         create_graph=create_graph,
#     362         inputs=inputs)
# --> 363 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File c:\Users\Felipe de Jesus\miniconda3\envs\FLearn\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
# graficar el resultado
plt.plot(Trn_loss, label='Training Loss')
plt.plot(Val_loss, label='Validation Loss')
plt.legend()

# %%
plot_model(O3Pred, X_test[0:100], y_test[0:100], O3Only=True)
# Out:
# torch.Size([1, 1, 64])
# torch.Size([100, 8])
# Test Loss: 0.773102
# torch.Size([1, 100, 8])
# torch.Size([100, 8])
# c:\Users\Felipe de Jesus\miniconda3\envs\FLearn\lib\site-packages\torch\nn\modules\loss.py:529: UserWarning: Using a target size (torch.Size([100, 8])) that is different to the input size (torch.Size([1, 100, 8])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
# salvar el modelo
torch.save(O3Pred.state_dict(), 'Model/O3Pred.pt')

# %%
# predict_n
def predict_n(model, X_test, y_test, n, m):
    restults = []
    ground_truth = []
    model.eval()
    with torch.no_grad():
        hidden = model.init_hidden(1)
        output, hidden = model(X_test[0:m].unsqueeze(0), hidden)
        # empezar a evaluar con el output como input
        for i in range(m, m+n):
            output, hidden = model(output, hidden)
            # mostrar el resultado
            print('Prediction: {:.6f}'.format(output.detach().cpu().numpy()[0,0,2]))
            print('Ground Truth: {:.6f}'.format(y_test[i,2]))
            restults.append(output.detach().cpu().numpy()[0,0,2].item())
            ground_truth.append(y_test[i,2].item())
        # mostrar el resultado
    return (restults, ground_truth)

# %%
(pred, out) = predict_n(O3Pred, X_test, y_test, 100, 700)
# Out:
# Prediction: -0.069804
# Ground Truth: 0.597012
# Prediction: -0.022760
# Ground Truth: -0.821981
# Prediction: -0.035872
# Ground Truth: -0.774682
# Prediction: -0.043242
# Ground Truth: -0.443583
# Prediction: -0.036585
# Ground Truth: 0.928110
# Prediction: -0.037605
# Ground Truth: 1.164609
# Prediction: -0.037755
# Ground Truth: 1.590307
# Prediction: -0.037810
# Ground Truth: 1.779506
# Prediction: -0.037714
# Ground Truth: 2.157904
# Prediction: -0.037749
# Ground Truth: 2.347103
# Prediction: -0.037743
# Ground Truth: 2.772801
# Prediction: -0.037744
# Ground Truth: -0.065185
# Prediction: -0.037744
# Ground Truth: 2.252504
# Prediction: -0.037744
# Ground Truth: 0.455112
# Prediction: -0.037744
# Ground Truth: -0.159785
# Prediction: -0.037744
# Ground Truth: -0.727382
# Prediction: -0.037744
# Ground Truth: -0.963881
# Prediction: -0.037744
# Ground Truth: -0.916581
# Prediction: -0.037744
# Ground Truth: -0.443583
# Prediction: -0.037744
# Ground Truth: -0.727382
# Prediction: -0.037744
# Ground Truth: -0.680082
# Prediction: -0.037744
# Ground Truth: -0.916581
# Prediction: -0.037744
# Ground Truth: -0.490883
# Prediction: -0.037744
# Ground Truth: -0.396283
# Prediction: -0.037744
# Ground Truth: -0.538183
# Prediction: -0.037744
# Ground Truth: -0.254384
# Prediction: -0.037744
# Ground Truth: 1.495707
# Prediction: -0.037744
# Ground Truth: -0.490883
# Prediction: -0.037744
# Ground Truth: -0.301684
# Prediction: -0.037744
# Ground Truth: -0.632782
# Prediction: -0.037744
# Ground Truth: -0.585483
# Prediction: -0.037744
# Ground Truth: -0.301684
# Prediction: -0.037744
# Ground Truth: 0.265913
# Prediction: -0.037744
# Ground Truth: 1.117309
# Prediction: -0.037744
# Ground Truth: 1.826806
# Prediction: -0.037744
# Ground Truth: 2.583602
# Prediction: -0.037744
# Ground Truth: 2.772801
# Prediction: -0.037744
# Ground Truth: 2.157904
# Prediction: -0.037744
# Ground Truth: 1.590307
# Prediction: -0.037744
# Ground Truth: 0.549712
# Prediction: -0.037744
# Ground Truth: -0.680082
